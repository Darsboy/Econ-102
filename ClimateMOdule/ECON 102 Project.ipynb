# %%
import pandas as pd

# %%
df = pd.read_csv('https://learn.uwaterloo.ca/content/enforced/628893-ECON102_081_cel_1211/lecture-content/week1/1410028701-eng.csv?_&d2lSessionVal=wCIRLYGGQRaRdyWMPd5wZ4WUT&ou=628893')

# %%
df
# Out:
#          Unnamed: 0  Canada  Newfoundland and Labrador  Prince Edward Island  \
# 0      January 1976     8.1                       14.3                  11.5
# 1     February 1976     8.0                       14.6                  13.3
# 2        March 1976     7.6                       14.8                  10.7
# 3        April 1976     7.5                       16.0                  11.8
# 4          May 1976     6.8                       13.8                   8.7
# ..              ...     ...                        ...                   ...
# 524  September 2019     5.0                        9.6                   6.3
# 525    October 2019     5.0                       10.0                   6.7
# 526   November 2019     5.5                       11.0                   8.1
# 527   December 2019     5.1                       12.1                   8.8
# 528    January 2020     5.8                       13.5                   9.7
#
#      Nova Scotia  New Brunswick  Quebec  Ontario  Manitoba  Saskatchew#an  \
# 0            9.0           12.3     9.1      7.2       6.7            5.0
# 1            9.4           12.3     9.7      6.9       5.8            5.5
# 2            9.4           12.6     8.7      6.9       5.4            5.0
# 3            9.8           12.7     8.9      6.4       4.7            4.4
# 4            9.0           12.0     7.8      5.9       4.0            3.3
# ..           ...            ...     ...      ...       ...            ...
# 524          6.4            6.4     4.2      5.0       4.5            4.8
# 525          7.4            6.9     4.3      4.8       4.8            4.4
# 526          8.0            7.3     5.0      5.0       5.3            5.6
# 527          7.6            6.8     4.8      4.7       4.5            5.2
# 528          8.0            9.1     5.6      5.2       5.2            6.2
#
#      Alberta  British Columbia
# 0        5.3              10.1
# 1        4.4               9.4
# 2        4.7               8.7
# 3        4.2               9.4
# 4        4.2               9.0
# ..       ...               ...
# 524      6.2               4.7
# 525      6.4               4.7
# 526      6.8               5.0
# 527      6.5               4.3
# 528      7.6               4.8
#
# [529 rows x 12 columns]

# %%
df.set_index('Unnamed: 0')
# Out:
#                 Canada  Newfoundland and Labrador  Prince Edward Island  \
# Unnamed: 0
# January 1976       8.1                       14.3                  11.5
# February 1976      8.0                       14.6                  13.3
# March 1976         7.6                       14.8                  10.7
# April 1976         7.5                       16.0                  11.8
# May 1976           6.8                       13.8                   8.7
# ...                ...                        ...                   ...
# September 2019     5.0                        9.6                   6.3
# October 2019       5.0                       10.0                   6.7
# November 2019      5.5                       11.0                   8.1
# December 2019      5.1                       12.1                   8.8
# January 2020       5.8                       13.5                   9.7
#
#                 Nova Scotia  New Brunswick  Quebec  Ontario  Manitoba  \
# Unnamed: 0
# January 1976            9.0           12.3     9.1      7.2       6.7
# February 1976           9.4           12.3     9.7      6.9       5.8
# March 1976              9.4           12.6     8.7      6.9       5.4
# April 1976              9.8           12.7     8.9      6.4       4.7
# May 1976                9.0           12.0     7.8      5.9       4.0
# ...                     ...            ...     ...      ...       ...
# September 2019          6.4            6.4     4.2      5.0       4.5
# October 2019            7.4            6.9     4.3      4.8       4.8
# November 2019           8.0            7.3     5.0      5.0       5.3
# December 2019           7.6            6.8     4.8      4.7       4.5
# January 2020            8.0            9.1     5.6      5.2       5.2
#
#                 Saskatchew#an  Alberta  British Columbia
# Unnamed: 0
# January 1976              5.0      5.3              10.1
# February 1976             5.5      4.4               9.4
# March 1976                5.0      4.7               8.7
# April 1976                4.4      4.2               9.4
# May 1976                  3.3      4.2               9.0
# ...                       ...      ...               ...
# September 2019            4.8      6.2               4.7
# October 2019              4.4      6.4               4.7
# November 2019             5.6      6.8               5.0
# December 2019             5.2      6.5               4.3
# January 2020              6.2      7.6               4.8
#
# [529 rows x 11 columns]

# %%
import chart_studio.plotly as py
import plotly.graph_objs as go 
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

# %%
data = dict(type = 'choropleth',
            locations = ['AZ','CA','NY'],
            locationmode = 'USA-states',
            colorscale= 'Portland',
            text= ['text1','text2','text3'],
            z=[1.0,2.0,3.0],
            colorbar = {'title':'Colorbar Title'})
